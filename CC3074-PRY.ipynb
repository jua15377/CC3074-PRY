# %%
import pandas as pd
vehiculos = pd.read_csv("VehiculosInvolucradosLimpio.csv")
hechos = pd.read_csv("HechosTransitoLimpio.csv")

# %%
vehiculos
hechos
# Out:
#        Unnamed: 0  dia_ocu  mes_ocu  ano_ocu  dia_sem_ocu  hora_ocu  \
# 0               1        1        1     2009            4         7
# 1               2        1        1     2009            4         8
# 2               3        1        1     2009            4         8
# 3               4        1        1     2009            4        10
# 4               5        1        1     2009            4        10
# 5               6        1        1     2009            4        11
# 6               7        1        1     2009            4        12
# 7               8        1        1     2009            4        13
# 8               9        1        1     2009            4        15
# 9              10        1        1     2009            4        15
# 10             11        1        1     2009            4        16
# 11             12        1        1     2009            4        16
# 12             13        1        1     2009            4        16
# ...
